# %%
#IMPORTING THE PACKAGES REQUIRED 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#READING THE DATASET AND USING DATA AS AN OBJECT TO REFER 
data=pd.read_csv(r"C:\Users\user\Downloads\StudentsPerformance.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
#TO FIND THE NUMBER OF MALE AND FEMALE PARTICIPATING IN THE TEST
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#TO FIND THE NUMBER OF MALE AND FEMALE PARTICIPATING IN THE TEST: GRAPHICAL TEST
sns.countplot(data=data,x='gender')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
#TO FIND INSIGHTS ABOUT THE STUDENTS' PARENTAL LEVEL OF EDUCATION
ple=data.groupby(["parental level of education"]).describe()
ple
# Out:
#                             math score                                     \
#                                  count       mean        std   min    25%
# parental level of education
# associate's degree               222.0  67.977477  15.108190  26.0  57.00
# bachelor's degree                118.0  69.288136  15.164117  29.0  61.00
# high school                      196.0  61.821429  15.160466   8.0  53.75
# master's degree                   59.0  70.254237  14.843544  40.0  57.00
# some college                     226.0  67.128319  14.871790  11.0  59.00
# some high school                 179.0  63.134078  16.602894   0.0  53.00
#
#                                                reading score             ...  \
#                               50%   75%    max         count       mean  ...
# parental level of education                                              ...
# associate's degree           67.0  80.0  100.0         222.0  71.018018  ...
# ...

# %%
#TO FIND INSIGHTS ABOUT THE STUDENTS' PARENTAL LEVEL OF EDUCATION: GRAPHICAL REPRESENTATION
plt.boxplot(data['parental level of education'].value_counts())
plt.show()

# %%
#ANALYSING STUDENTS SCORE AND PARENTAL LEVEL OF EDUCATION
math_score = ple['math score']
reading = ple['reading score']
writing = ple['writing score']

# %%
reading['mean'].nlargest()
# Out:
# parental level of education
# master's degree       75.949153
# bachelor's degree     73.000000
# associate's degree    71.018018
# some college          69.566372
# some high school      66.759777
# Name: mean, dtype: float64

# %%
writing['mean'].nlargest()
# Out:
# parental level of education
# master's degree       75.677966
# bachelor's degree     73.381356
# associate's degree    70.031532
# some college          69.035398
# some high school      64.888268
# Name: mean, dtype: float64

# %%
math_score['mean'].nlargest()
# Out:
# parental level of education
# master's degree       70.254237
# bachelor's degree     69.288136
# associate's degree    67.977477
# some college          67.128319
# some high school      63.134078
# Name: mean, dtype: float64

# %% [raw]
# This shows how students who score better come from a background of parents with master's degree.

# %%
gender_based_scores=data.groupby(["gender"]).describe()
gender_based_scores
# Out:
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      518.0  63.376448  16.029928   0.0  54.0  65.0  74.0  100.0
# male        482.0  68.821577  14.556411  27.0  59.0  69.0  79.0  100.0
#
#        reading score             ...              writing score             \
#                count       mean  ...   75%    max         count       mean
# gender                           ...
# female         518.0  72.590734  ...  83.0  100.0         518.0  72.467181
# male           482.0  65.545643  ...  76.0  100.0         482.0  63.446058
#
#
#               std   min   25%   50%   75%    max
# gender
# female  14.844842  10.0  64.0  74.0  82.0  100.0
# male    14.227225  15.0  53.0  64.0  74.0  100.0
#
# [2 rows x 24 columns]

# %%
gender_math = gender_based_scores['math score']
gender_reading = gender_based_scores['reading score']
gender_writing = gender_based_scores['writing score']

# %%
gender_math['mean'].nlargest()
# Out:
# gender
# male      68.821577
# female    63.376448
# Name: mean, dtype: float64

# %%
gender_reading['mean'].nlargest()
# Out:
# gender
# female    72.590734
# male      65.545643
# Name: mean, dtype: float64

# %%
gender_writing['mean'].nlargest()
# Out:
# gender
# female    72.467181
# male      63.446058
# Name: mean, dtype: float64

# %% [raw]
# For reading and writing score, female students scored more, while in the case of math, male students scored more.

# %%
data.groupby(["test preparation course"])["math score"].mean()
# Out:
# test preparation course
# completed    69.96648
# none         63.78972
# Name: math score, dtype: float64

# %%
data.groupby(["test preparation course"])["reading score"].mean()
# Out:
# test preparation course
# completed    74.175978
# none         66.417445
# Name: reading score, dtype: float64

# %%
data.groupby(["test preparation course"])["writing score"].mean()
# Out:
# test preparation course
# completed    74.684358
# none         64.457944
# Name: writing score, dtype: float64

# %%
test=data.groupby(["test preparation course"]).describe()
test
# Out:
#                         math score                                         \
#                              count      mean        std   min   25%   50%
# test preparation course
# completed                    358.0  69.96648  14.521847  23.0  61.0  70.0
# none                         642.0  63.78972  15.705689   0.0  54.0  64.0
#
#                                      reading score             ...        \
#                           75%    max         count       mean  ...   75%
# test preparation course                                        ...
# completed                79.0  100.0         358.0  74.175978  ...  84.0
# none                     74.0  100.0         642.0  66.417445  ...  76.0
#
#                                writing score                              \
#                            max         count       mean        std   min
# test preparation course
# completed                100.0         358.0  74.684358  13.236412  36.0
# ...

# %% [raw]
#  Students who did test preparation course have higher average score across all categories

# %%
#TO STORE DATA OF TOP 25%
data["math score"].quantile(0.75)
top = data[data["math score"] >= 77].sort_values("math score",ascending=False)
top
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 854    male        group D            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 856    male        group E            some high school      standard
# 415  female        group B             master's degree  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [raw]
#  List of top 250 students who are eligible for bonus points wiil be in top 25% csv file
